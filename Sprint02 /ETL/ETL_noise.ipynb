# %%
import pandas as pd

# %%
df = pd.read_csv('noise_pollution.csv')

# %%
df
# Out:
#        id_borough borough_name  year  week  day  hour  engine_sounds  \
# 0               1    manhattan  2019    43    4     8              4
# 1               1    manhattan  2019    43    4     8              1
# 2               1    manhattan  2019    43    4     8              1
# 3               1    manhattan  2019    43    4     8              4
# 4               1    manhattan  2019    43    4     8              2
# ...           ...          ...   ...   ...  ...   ...            ...
# 62017           1    manhattan  2018    42    5    19              0
# 62018           1    manhattan  2018    42    5    19              0
# 62019           1    manhattan  2018    34    2     9              0
# 62020           1    manhattan  2018    34    2     9              0
# 62021           1    manhattan  2018    34    2     9              1
#
#        alarm_sounds
# 0                 5
# 1                 5
# 2                 5
# 3                 5
# 4                 0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62022 entries, 0 to 62021
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_borough     62022 non-null  int64
#  1   borough_name   62022 non-null  object
#  2   year           62022 non-null  int64
#  3   week           62022 non-null  int64
#  4   day            62022 non-null  int64
#  5   hour           62022 non-null  int64
#  6   engine_sounds  62022 non-null  int64
#  7   alarm_sounds   62022 non-null  int64
# dtypes: int64(7), object(1)
# memory usage: 3.8+ MB

# %%
df.describe()
# Out:
#          id_borough          year          week           day          hour  \
# count  62022.000000  62022.000000  62022.000000  62022.000000  62022.000000
# mean       1.114943   2017.591000     26.274838      2.907259     12.417578
# std        0.472653      0.778948     16.169650      1.925728      5.824993
# min        1.000000   2016.000000      1.000000      0.000000      0.000000
# 25%        1.000000   2017.000000     12.000000      1.000000      8.000000
# 50%        1.000000   2017.000000     27.000000      3.000000     12.000000
# 75%        1.000000   2018.000000     41.000000      4.000000     17.000000
# max        4.000000   2019.000000     52.000000      6.000000     23.000000
#
#        engine_sounds  alarm_sounds
# count   62022.000000  62022.000000
# mean        0.542162      0.525572
# std         0.991777      1.306233
# min         0.000000      0.000000
# 25%         0.000000      0.000000
# 50%         0.000000      0.000000
# ...

# %%
muestra_np = df.head(60)

# %%
muestra_np.to_csv('muestra_contaminacion_sonora.csv',index=False)

# %%
df2 = pd.read_csv('noise_pollution2016-2019.csv')

# %%
df2
# Out:
#      year  month  day  id_borough  engine_sounds  alert_signal_sounds  \
# 0    2016      1    0           1             15                    7
# 1    2016      5    0           1             20                   23
# 2    2016      5    1           1              5                    3
# 3    2016      5    2           1              9                   14
# 4    2016      5    3           1              4                    3
# ..    ...    ...  ...         ...            ...                  ...
# 502  2019     12    5           1             81                   99
# 503  2019     12    5           3             24                   30
# 504  2019     12    5           4              5                   10
# 505  2019     12    6           1             41                   49
# 506  2019     12    6           3              5                   10
#
#      total_sounds borough_name
# 0              22    manhattan
# 1              43    manhattan
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 507 entries, 0 to 506
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year                 507 non-null    int64
#  1   month                507 non-null    int64
#  2   day                  507 non-null    int64
#  3   id_borough           507 non-null    int64
#  4   engine_sounds        507 non-null    int64
#  5   alert_signal_sounds  507 non-null    int64
#  6   total_sounds         507 non-null    int64
#  7   borough_name         507 non-null    object
# dtypes: int64(7), object(1)
# memory usage: 31.8+ KB

# %%
df2.isna().sum()
# Out:
# year                   0
# month                  0
# day                    0
# id_borough             0
# engine_sounds          0
# alert_signal_sounds    0
# total_sounds           0
# borough_name           0
# dtype: int64

# %%
df2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # TRANSFORMAMOS LAS FECHAS PARA NORMALIZARLO CON LOS DEMAS DATASETS

# %%
df_final = df2[df2['day'] != 0]

# %%
# Combinamos las columnas 'año', 'mes' y 'día' en una columna 'fecha'
df_final['fecha'] = pd.to_datetime(df_final['year'].astype(str) + '-' + df_final['month'].astype(str).str.zfill(2) + '-' + df_final['day'].astype(str))
# Out:
# C:\Users\PEDRO\AppData\Local\Temp\ipykernel_3136\1841487651.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['fecha'] = pd.to_datetime(df_final['year'].astype(str) + '-' + df_final['month'].astype(str).str.zfill(2) + '-' + df_final['day'].astype(str))

# %%
df_final
# Out:
#      year  month  day  id_borough  engine_sounds  alert_signal_sounds  \
# 2    2016      5    1           1              5                    3
# 3    2016      5    2           1              9                   14
# 4    2016      5    3           1              4                    3
# 5    2016      5    4           1              9                    1
# 6    2016      5    5           1              4                    0
# ..    ...    ...  ...         ...            ...                  ...
# 502  2019     12    5           1             81                   99
# 503  2019     12    5           3             24                   30
# 504  2019     12    5           4              5                   10
# 505  2019     12    6           1             41                   49
# 506  2019     12    6           3              5                   10
#
#      total_sounds borough_name      fecha
# 2               8    manhattan 2016-05-01
# ...

# %%
df_final = df_final[['fecha','id_borough','engine_sounds','alert_signal_sounds','total_sounds','borough_name']]

# %%
df_final
# Out:
#          fecha  id_borough  engine_sounds  alert_signal_sounds  total_sounds  \
# 2   2016-05-01           1              5                    3             8
# 3   2016-05-02           1              9                   14            23
# 4   2016-05-03           1              4                    3             7
# 5   2016-05-04           1              9                    1            10
# 6   2016-05-05           1              4                    0             4
# ..         ...         ...            ...                  ...           ...
# 502 2019-12-05           1             81                   99           180
# 503 2019-12-05           3             24                   30            54
# 504 2019-12-05           4              5                   10            15
# 505 2019-12-06           1             41                   49            90
# 506 2019-12-06           3              5                   10            15
#
#     borough_name
# 2      manhattan
# ...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 434 entries, 2 to 506
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   fecha                434 non-null    datetime64[ns]
#  1   id_borough           434 non-null    int64
#  2   engine_sounds        434 non-null    int64
#  3   alert_signal_sounds  434 non-null    int64
#  4   total_sounds         434 non-null    int64
#  5   borough_name         434 non-null    object
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 23.7+ KB

# %%
df_final.isna().sum()
# Out:
# fecha                  0
# id_borough             0
# engine_sounds          0
# alert_signal_sounds    0
# total_sounds           0
# borough_name           0
# dtype: int64

# %%
df_final.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # ANALISIS PRELIMINAR DE LOS DATASETS
#
# - Features:
#     - fecha: Fecha de las observaciones (datetime64[ns])
#     - id_borough: ID del distrito (int64)
#     - engine_sounds: Cantidad de sonidos de motor registrados (int64)
#     - alert_signal_sounds: Cantidad de sonidos de señal de alerta registrados (int64)
#     - total_sounds: Cantidad total de sonidos registrados (int64)
#     - borough_name: Nombre del distrito (object)
#
# - Análisis del dataset:
#   - Los datos proporcionan información sobre sonidos registrados en diferentes distritos en fechas específicas.
#   - La columna "fecha" contiene fechas y horas de las observaciones en formato datetime.
#   - Las columnas numéricas representan la cantidad de sonidos registrados en cada categoría.
#   - La columna "borough_name" proporciona los nombres de los distritos asociados a los datos.
#
# - Conclusiones:
#   - Estos datos son valiosos para analizar y comprender los niveles de ruido en diferentes distritos en función de los sonidos registrados.
#   - El análisis de estos datos puede ayudar a identificar patrones de ruido, áreas con mayor concentración de sonidos y tendencias en el tiempo.
#   - Con este conjunto de datos, se pueden realizar análisis detallados para abordar cuestiones relacionadas con el ruido y la planificación urbana.
